# %%
from datetime import datetime
from pathlib import Path

# %%
log_dir = Path("logs")
run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
log_file_path = log_dir / f"{run_id}.log"

print(f"log_file_path: {log_file_path}")
# Out:
# log_file_path: logs\2026-02-12_19-25-43.log

# %%
from datetime import datetime
from pathlib import Path

log_dir = Path("logs")
log_dir.mkdir(exist_ok=True)

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
log_file_path = log_dir / f"{run_id}.log"

print(log_file_path)
# Out:
# logs\2026-02-12_22-33-54.log

# %%
import zipfile
from pathlib import Path 

raw_data_dir = Path("data/raw/archive.zip")
dest_data_dir = Path("data/processed")

dest_data_dir.
with open(raw_data_dir, "r") as zip_ref:

# %%
from pathlib import Path 

model_path = Path(r"E:\project_archive\MoodNet\artifacts\models\ResNet18.pth")

if not model_path.exists():
    print("model path not exist")
